# %% [markdown]
# # pydyneval — R⇄Py function dictionary
#
# | R | Python | Status |
# |---|---|---|
# | `calculate_metrics(dataset, model, metrics)` | same | ✅ |
# | `calculate_him(net1, net2)` | same | ✅ Lorentzian inline |
# | `calculate_edge_flip(net1, net2)` | same | ✅ Jaccard surrogate |
# | `calculate_featureimp_cor(dataset, model)` | same | ✅ |

# %%
import sys; sys.path.insert(0,'..')
import pydyneval as de, pydynwrap as dw, numpy as np, pandas as pd
mn = pd.DataFrame({'from':['A','A'],'to':['B','C'],'length':[1.0,1.0]})
print('him(mn, mn):', de.calculate_him(mn, mn))    # 1.0 perfect
print('edge_flip(mn, mn):', de.calculate_edge_flip(mn, mn))
# Out:
# him(mn, mn): 1.0
# edge_flip(mn, mn): 1.0
